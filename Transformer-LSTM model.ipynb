# %% [markdown]
# <a href="https://colab.research.google.com/github/deburg0/ROS-sandbox/blob/main/Transformer-LSTM%20model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This Jupyter Notebook implements the hybrid Transformer–LSTM model described in the manuscript, designed for
#  time-series classification of cell malignancy based on mechanistic simulation outputs.
#  The model integrates transformer-based self-attention for capturing long-range dependencies
#  with LSTM sequence modeling for temporal dynamics. The script supports .npz input datasets
#  containing multi-stressor profiles (ROS, pH, temperature, ion channel conductances, etc.)
#  and outputs predicted malignancy classes.
#
#  Select T4 runtime

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
import pandas as pd

# %% [markdown]
# #### Model Definition

# %%
class TransformerLSTM(nn.Module):
    def __init__(self, input_dim, d_model=64, nhead=4, num_layers=2, lstm_hidden=64, num_classes=2):
        super(TransformerLSTM, self).__init__()
        self.input_fc = nn.Linear(input_dim, d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.lstm = nn.LSTM(d_model, lstm_hidden, batch_first=True)
        self.fc_out = nn.Linear(lstm_hidden, num_classes)

    def forward(self, x):
        x = self.input_fc(x)  # (batch, seq_len, d_model)
        x = self.transformer_encoder(x)
        lstm_out, _ = self.lstm(x)
        out = self.fc_out(lstm_out[:, -1, :])  # take last time step
        return out

# %% [markdown]
# #### Load Data

# %%
def load_npz(path):
    data = np.load(path)
    X = data['X']  # shape: (samples, timesteps, features)
    y = data['y']  # shape: (samples,)
    return X, y

# %% [markdown]
# #### Train Function

# %%
def train_model(X, y, num_epochs=50, batch_size=16, lr=1e-3):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    n_samples, seq_len, n_features = X.shape

    model = TransformerLSTM(input_dim=n_features).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    dataset = TensorDataset(torch.tensor(X, dtype=torch.float32), torch.tensor(y, dtype=torch.long))
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    model.train()
    for epoch in range(num_epochs):
        epoch_loss = 0
        for X_batch, y_batch in loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss/len(loader):.4f}")

    return model

# %% [markdown]
# #### Evaluation

# %%
def evaluate_model(model, X, y):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    with torch.no_grad():
        outputs = model(torch.tensor(X, dtype=torch.float32).to(device))
        preds = torch.argmax(outputs, dim=1).cpu().numpy()
        acc = accuracy_score(y, preds)
        auc = roc_auc_score(y, preds)
        cm = confusion_matrix(y, preds)
    return acc, auc, cm, preds

# %%
# Upload .npz File
# For this file R_th = 0.09
# R_th may reflect the effective buffering capacity or redox tolerance threshold set by NRF2-regulated antioxidant gene expression

# !wget https://raw.githubusercontent.com/deburg0/ROS-sandbox/main/omics_informed_demo.npz
# Out:
# --2026-03-02 21:11:09--  https://raw.githubusercontent.com/deburg0/ROS-sandbox/main/omics_informed_demo.npz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 926380 (905K) [application/octet-stream]
# Saving to: ‘omics_informed_demo.npz’
#
# omics_informed_demo 100%[===================>] 904.67K  --.-KB/s    in 0.03s
#
# 2026-03-02 21:11:10 (34.7 MB/s) - ‘omics_informed_demo.npz’ saved [926380/926380]

# %%
# Path to NPZ time-series dataset (change this to your file)
npz_path = "omics_informed_demo.npz"
X, y = load_npz(npz_path)

# %%
model = train_model(X, y, num_epochs=50, batch_size=16, lr=1e-3)

acc, auc, cm, preds = evaluate_model(model, X, y)
print("Accuracy:", acc)
print("AUC:", auc)
print("Confusion Matrix:\n", cm)
# Out:
# Epoch 1/50, Loss: 0.5720
# Epoch 2/50, Loss: 0.3429
# Epoch 3/50, Loss: 0.2664
# Epoch 4/50, Loss: 0.1766
# Epoch 5/50, Loss: 0.1272
# Epoch 6/50, Loss: 0.0623
# Epoch 7/50, Loss: 0.0411
# Epoch 8/50, Loss: 0.0363
# Epoch 9/50, Loss: 0.1401
# Epoch 10/50, Loss: 0.0366
# Epoch 11/50, Loss: 0.0152
# Epoch 12/50, Loss: 0.0313
# Epoch 13/50, Loss: 0.0143
# Epoch 14/50, Loss: 0.0167
# Epoch 15/50, Loss: 0.0363
# Epoch 16/50, Loss: 0.0105
# Epoch 17/50, Loss: 0.0313
# Epoch 18/50, Loss: 0.0840
# Epoch 19/50, Loss: 0.0596
# Epoch 20/50, Loss: 0.0211
# Epoch 21/50, Loss: 0.0185
# Epoch 22/50, Loss: 0.0074
# Epoch 23/50, Loss: 0.0152
# Epoch 24/50, Loss: 0.0043
# Epoch 25/50, Loss: 0.0050
# Epoch 26/50, Loss: 0.0033
# Epoch 27/50, Loss: 0.0022
# Epoch 28/50, Loss: 0.0020
# Epoch 29/50, Loss: 0.0018
# Epoch 30/50, Loss: 0.0017
# Epoch 31/50, Loss: 0.0016
# Epoch 32/50, Loss: 0.0015
# Epoch 33/50, Loss: 0.0014
# Epoch 34/50, Loss: 0.0013
# Epoch 35/50, Loss: 0.0012
# Epoch 36/50, Loss: 0.0011
# Epoch 37/50, Loss: 0.0011
# Epoch 38/50, Loss: 0.0010
# Epoch 39/50, Loss: 0.0010
# Epoch 40/50, Loss: 0.0009
# Epoch 41/50, Loss: 0.0009
# Epoch 42/50, Loss: 0.0009
# Epoch 43/50, Loss: 0.0008
# Epoch 44/50, Loss: 0.0008
# Epoch 45/50, Loss: 0.0008
# Epoch 46/50, Loss: 0.0007
# Epoch 47/50, Loss: 0.0007
# Epoch 48/50, Loss: 0.0007
# Epoch 49/50, Loss: 0.0007
# Epoch 50/50, Loss: 0.0007
# Accuracy: 1.0
# AUC: 1.0
# Confusion Matrix:
#  [[48  0]
#  [ 0 32]]

# %%
 # Save Model Weights

torch.save(model.state_dict(), 'model_weights.pth')

# %%
# Save predictions to Excel
df_preds = pd.DataFrame({
    "y_true": y,
    "y_pred": preds
})
df_preds.to_excel("transformer_lstm_results.xlsx", index=False)
print("Results saved to transformer_lstm_results.xlsx")
# Out:
# Results saved to transformer_lstm_results.xlsx

# %%
# Results are save to local file space which is transient. To save results download to your harddrive.
